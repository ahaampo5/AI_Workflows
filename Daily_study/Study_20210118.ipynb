# %% [markdown]
# # **학업일지**

# %% [markdown]
# #### 오늘의 한마디
# > **어떤 환경에도 익숙해지도록 다양한 개발 경험 쌓기**

# %% [markdown]
# ## 1. 강의 정리
# ### 1.1 Console, terminal, shell에 대한 개념 정리
# - Console : 역사적으로 메인 컴퓨터와 이어지는 하드웨어를 의미하고 현재는 터미널과 같은의미로 쓰인다.
# - Terminal :

# %% [markdown]
# ### 1.2 Jupyter notebook의 단축키
# ctrl + shift + - : 위 아래 나누기
# shift + m : 아래 셀과 합치기
# dd : 셀 삭제
# b : 아래로 셀 추가

# %% [markdown]
# ### 1.3 개발 환경 구축

# %% [markdown]
# - OS
# Windows
# Ubuntu : Windows 환경에서 Linux 단축키와 프로젝트 작업에 쓰기 좋다.
#
# - terminal
# cmder : ssh 와 달리 자동완성기능이 있어 편하게 쓸 때 유용하다.
# windows terminal : Ubuntu 환경외에 다양한 쉘을 사용하기 편하다.
#
# - shell
# python shell :
# Power shell : 윈도우 환경에서 익숙해지면 좋을 것 같아 차후 공부 예정
#
# - 에디터
# VScode : 프로그램 자체가 매우 무겁지만 다양한 단축키가 편하고 여러 확장팩을 쉽게 추가할 수 있어 편리하다.
# Jupyter notebook : 단순한 코드 체크나 구간별로 확인하기 쉽기 때문에 작은 코드들을 확인할 때 사용하기 좋다.

# %% [markdown]
# ## 2. 피어세션

# %% [markdown]
# ### 2.1 피어세션 룰 지정
# - 개인 공부 이후 질문 작성 후 공유
# - numpy, pandas 유용한 함수 공유
# - 논문 하나 정해서 익숙해지도록 연습

# %% [markdown]
# ## 3. 진행중인 공부 및 신규 공부 목록

# %% [markdown]
# ### 3.1 신규 공부 목록
# - Vim 에디터 사용법 숙지
# <img src="https://gmlwjd9405.github.io/images/etc/vim-shortkey-keyboard.png" width="450px" height="300px" title="title" alt="RubberDuck"></img><br/>

# %% [markdown]
# - Linux, windows의 터미널 단축키 숙지
#
# | 명령 | Windows | Linux |
# |:---------|:----------|:--------|
# |파일복사|copy     | cp    |
# |파일이동|move     |mv     |
# |파일 목록보기|dir|ls|
# |파일 삭제|del,erase|rm|
# |이름 변경|move|mv|
# |디렉토리 이동|cd|cd|
# |현재 디렉토리|cd|pwd|
# |화면 정리|cls|clear|
# |파일 내용 표시|type|cat|
# |도움말|help|man|
# |종료|exit|exit|
# |시간표시|time|date|
# |버전 정보|ver|uname -a|
# |파일 문자열 찾기|find|find|
# |압축|pkzip|tar, zip|
# |프로세스 정보|taskmgr|ps, top|
# |프로세스 종료|tskill|kill, killall|

# %% [markdown]
# - Markdown 명령어
#
#  - '#' 부호로 타이틀 문자 크기 조절
#  - '>' 부호로 들여쓰기
#  - |, :-- 를 이용하여 table 만들기
#  - 인터넷에서 이미지 파일 주소로 가져오기
#    - [`<image_name>`](`<image path>`)
#    - `<img src="/path/to/img.jpg" width="450px" height="300px" title="title" alt="RubberDuck"></img><br/>`
#  - 들여쓰기를 쓰면 전체 행이 블록처리 된다.

# %% [markdown]
# ### 3. 인용
#     https://eungbean.github.io/2018/06/11/How-to-use-markdown/: 마크다운 사용법
#     https://gmlwjd9405.github.io/2019/05/14/vim-shortkey.html: vim 단축키
#     https://kkokkilkon.tistory.com/151 : jupyter nootbook 단축키

# %% [markdown]
# ### 4. 감사한 것
# 1. 마크다운에 대한 언급을 한 조원 김상현님에게 감사합니다
# 2. 오늘 첫날인데 불구하고 팀원간 소통할 수 있도록 리더의 역할을 한 이주남님에게 감사합니다
# 3. 열심히 의견 수립하려한 팔색조 팀원들 감사합니다.
